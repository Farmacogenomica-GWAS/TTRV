# %% [markdown]
# ##Script to Check for Data in Result Files

# %% [markdown]
# Drive Connection

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Libraries

# %%
import h5py
import os

# %% [markdown]
# Files

# %%
file_names = [
    '/content/drive/MyDrive/Worms/L1_featuresN.hdf5',
    '/content/drive/MyDrive/Worms/L1_intensities.hdf5',
    '/content/drive/MyDrive/Worms/L1_skeletons.hdf5',
    '/content/drive/MyDrive/Worms/L2_featuresN.hdf5',
    '/content/drive/MyDrive/Worms/L2_intensities.hdf5',
    '/content/drive/MyDrive/Worms/L2_skeletons.hdf5',
    '/content/drive/MyDrive/Worms/n2_featuresN.hdf5',
    '/content/drive/MyDrive/Worms/n2_intensities.hdf5',
    '/content/drive/MyDrive/Worms/n2_skeletons.hdf5'
]

# %% [markdown]
# Verifying File Content

# %%
for file_name in file_names:
    print(f"\n{'='*30}")
    print(f"Analyzing file: {file_name}")
    print(f"{'='*30}")
    try:
        with h5py.File(file_name, 'r') as hdfid:
            print(hdfid)
            print("\nHDF5 File Structure:")
            def print_name(name):
                print(f"  {name}")

            hdfid.visit(print_name)

            has_datasets = False
            print("\nContents of the datasets:")
            for key in hdfid.keys():
                if isinstance(hdfid[key], h5py.Dataset):
                    has_datasets = True
                    dataset = hdfid[key] # Get the dataset object
                    data_shape = dataset.shape
                    data_dtype = dataset.dtype
                    data_size = dataset.size

                    print(f"  Dataset: {key}")
                    print(f"    Shape: {data_shape}")
                    print(f"    Data Type: {data_dtype}")
                    print(f"    Number of Elements: {data_size}")
                    if dataset.ndim <= 2 and data_size < 100:
                        print("    First rows:")
                        print(dataset[:5])
                    else:
                        print("    (Dataset too large to print completely)")
                elif isinstance(hdfid[key], h5py.Group):
                    print(f"  Group: {key}")

            if not has_datasets and not hdfid.keys():
                print("  The file does not contain top-level datasets.")
            elif not has_datasets:
                print("  The file does not contain top-level datasets, only groups (see structure).")

    except FileNotFoundError:
        print(f"Error: File '{file_name}' not found.")
    except Exception as e:
        print(f"An error occurred while opening or reading the file: {e}")
# Out:
# ==============================
# Analyzing file: /content/drive/MyDrive/Worms/L1_featuresN.hdf5
# ==============================
# <HDF5 file "L1_featuresN.hdf5" (mode r)>
#
# HDF5 File Structure:
#   blob_features
#   coordinates
#   coordinates/dorsal_contours
#   coordinates/skeletons
#   coordinates/ventral_contours
#   coordinates/widths
#   features_stats
#   provenance_tracking
#   provenance_tracking/FEAT_INIT
#   provenance_tracking/FEAT_TIERPSY
#   timeseries_data
#   trajectories_data
#
# Contents of the datasets:
#   Dataset: blob_features
#     Shape: (21223,)
#     Data Type: [('coord_x', '<f8'), ('coord_y', '<f8'), ('area', '<f8'), ('perimeter', '<f8'), ('box_length', '<f8'), ('box_width', '<f8'), ('quirkiness', '<f4'), ('compactness', '<f4'), ('box_orientation', '<f4'), ('solidity', '<f4'), ('intensity_mean', '<f4'), ('intensity_std', '<f4'), ('hu0', '<f4'), ('hu1', '<f4'), ('hu2', '<f4'), ('hu3', '<f4'), ('hu4', '<f4'), ('hu5', '<f4'), ('hu6', '<f4')]
#     Number of Elements: 21223
#     (Dataset too large to print completely)
#   Group: coordinates
#   Dataset: features_stats
#     Shape: (4539,)
#     Data Type: [('name', 'S69'), ('value', '<f4')]
#     Number of Elements: 4539
#     (Dataset too large to print completely)
#   Group: provenance_tracking
#   Dataset: timeseries_data
#     Shape: (21223,)
#     Data Type: [('worm_index', '<i4'), ('timestamp', '<i4'), ('well_name', 'S3'), ('speed', '<f4'), ('angular_velocity', '<f4'), ('relative_to_body_speed_midbody', '<f4'), ('relative_to_body_radial_velocity_head_tip', '<f4'), ('relative_to_body_angular_velocity_head_tip', '<f4'), ('relative_to_body_radial_velocity_neck', '<f4'), ('relative_to_body_angular_velocity_neck', '<f4'), ('relative_to_body_radial_velocity_hips', '<f4'), ('relative_to_body_angular_velocity_hips', '<f4'), ('relative_to_body_radial_velocity_tail_tip', '<f4'), ('relative_to_body_angular_velocity_tail_tip', '<f4'), ('speed_neck', '<f4'), ('angular_velocity_neck', '<f4'), ('relative_to_neck_radial_velocity_head_tip', '<f4'), ('relative_to_neck_angular_velocity_head_tip', '<f4'), ('speed_head_base', '<f4'), ('angular_velocity_head_base', '<f4'), ('relative_to_head_base_radial_velocity_head_tip', '<f4'), ('relative_to_head_base_angular_velocity_head_tip', '<f4'), ('speed_hips', '<f4'), ('angular_velocity_hips', '<f4'), ('relative_to_hips_radial_velocity_tail_tip', '<f4'), ('relative_to_hips_angular_velocity_tail_tip', '<f4'), ('speed_tail_base', '<f4'), ('angular_velocity_tail_base', '<f4'), ('relative_to_tail_base_radial_velocity_tail_tip', '<f4'), ('relative_to_tail_base_angular_velocity_tail_tip', '<f4'), ('speed_midbody', '<f4'), ('angular_velocity_midbody', '<f4'), ('speed_head_tip', '<f4'), ('angular_velocity_head_tip', '<f4'), ('speed_tail_tip', '<f4'), ('angular_velocity_tail_tip', '<f4'), ('length', '<f4'), ('area', '<f4'), ('width_head_base', '<f4'), ('width_midbody', '<f4'), ('width_tail_base', '<f4'), ('quirkiness', '<f4'), ('major_axis', '<f4'), ('minor_axis', '<f4'), ('eigen_projection_1', '<f4'), ('eigen_projection_2', '<f4'), ('eigen_projection_3', '<f4'), ('eigen_projection_4', '<f4'), ('eigen_projection_5', '<f4'), ('eigen_projection_6', '<f4'), ('eigen_projection_7', '<f4'), ('curvature_head', '<f4'), ('curvature_hips', '<f4'), ('curvature_midbody', '<f4'), ('curvature_neck', '<f4'), ('curvature_tail', '<f4'), ('curvature_mean_head', '<f4'), ('curvature_mean_neck', '<f4'), ('curvature_mean_midbody', '<f4'), ('curvature_mean_hips', '<f4'), ('curvature_mean_tail', '<f4'), ('curvature_std_head', '<f4'), ('curvature_std_neck', '<f4'), ('curvature_std_midbody', '<f4'), ('curvature_std_hips', '<f4'), ('curvature_std_tail', '<f4'), ('orientation_food_edge', '<f4'), ('dist_from_food_edge', '<f4'), ('path_curvature_body', '<f4'), ('path_curvature_tail', '<f4'), ('path_curvature_midbody', '<f4'), ('path_curvature_head', '<f4'), ('d_speed', '<f4'), ('d_angular_velocity', '<f4'), ('d_relative_to_body_speed_midbody', '<f4'), ('d_relative_to_body_radial_velocity_head_tip', '<f4'), ('d_relative_to_body_angular_velocity_head_tip', '<f4'), ('d_relative_to_body_radial_velocity_neck', '<f4'), ('d_relative_to_body_angular_velocity_neck', '<f4'), ('d_relative_to_body_radial_velocity_hips', '<f4'), ('d_relative_to_body_angular_velocity_hips', '<f4'), ('d_relative_to_body_radial_velocity_tail_tip', '<f4'), ('d_relative_to_body_angular_velocity_tail_tip', '<f4'), ('d_speed_neck', '<f4'), ('d_angular_velocity_neck', '<f4'), ('d_relative_to_neck_radial_velocity_head_tip', '<f4'), ('d_relative_to_neck_angular_velocity_head_tip', '<f4'), ('d_speed_head_base', '<f4'), ('d_angular_velocity_head_base', '<f4'), ('d_relative_to_head_base_radial_velocity_head_tip', '<f4'), ('d_relative_to_head_base_angular_velocity_head_tip', '<f4'), ('d_speed_hips', '<f4'), ('d_angular_velocity_hips', '<f4'), ('d_relative_to_hips_radial_velocity_tail_tip', '<f4'), ('d_relative_to_hips_angular_velocity_tail_tip', '<f4'), ('d_speed_tail_base', '<f4'), ('d_angular_velocity_tail_base', '<f4'), ('d_relative_to_tail_base_radial_velocity_tail_tip', '<f4'), ('d_relative_to_tail_base_angular_velocity_tail_tip', '<f4'), ('d_speed_midbody', '<f4'), ('d_angular_velocity_midbody', '<f4'), ('d_speed_head_tip', '<f4'), ('d_angular_velocity_head_tip', '<f4'), ('d_speed_tail_tip', '<f4'), ('d_angular_veloci ...
#     Number of Elements: 21223
#     (Dataset too large to print completely)
#   Dataset: trajectories_data
#     Shape: (21223,)
#     Data Type: [('timestamp_raw', '<i4'), ('timestamp_time', '<f8'), ('worm_index_joined', '<i4'), ('coord_x', '<f4'), ('coord_y', '<f4'), ('threshold', '<f4'), ('roi_size', '<f4'), ('area', '<f4'), ('frame_number', '<i4'), ('was_skeletonized', 'u1'), ('skeleton_id', '<i8'), ('old_trajectory_data_index', '<i4'), ('worm_label', '<f8'), ('worm_index_manual', '<i8'), ('has_skeleton', 'u1')]
#     Number of Elements: 21223
#     (Dataset too large to print completely)
#
# ==============================
# Analyzing file: /content/drive/MyDrive/Worms/L1_intensities.hdf5
# ==============================
# <HDF5 file "L1_intensities.hdf5" (mode r)>
#
# HDF5 File Structure:
#   provenance_tracking
#   provenance_tracking/INT_PROFILE
#   straighten_worm_intensity_median
#   trajectories_data_valid
#
# Contents of the datasets:
#   Group: provenance_tracking
#   Dataset: straighten_worm_intensity_median
#     Shape: (17143, 131)
#     Data Type: float16
#     Number of Elements: 2245733
#     (Dataset too large to print completely)
#   Dataset: trajectories_data_valid
#     Shape: (17143,)
#     Data Type: [('frame_number', '<i4'), ('worm_index_joined', '<i4'), ('plate_worm_id', '<i4'), ('skeleton_id', '<i4'), ('coord_x', '<f4'), ('coord_y', '<f4'), ('threshold', '<f4'), ('has_skeleton', 'u1'), ('roi_size', '<f4'), ('area', '<f4'), ('timestamp_raw', '<f4'), ('timestamp_time', '<f4'), ('is_good_skel', 'u1'), ('skel_outliers_flag', '<i8'), ('int_map_id', '<i8')]
#     Number of Elements: 17143
#     (Dataset too large to print completely)
#
# ==============================
# Analyzing file: /content/drive/MyDrive/Worms/L1_skeletons.hdf5
# ==============================
# <HDF5 file "L1_skeletons.hdf5" (mode r)>
#
# HDF5 File Structure:
#   blob_features
#   contour_area
#   contour_side1
#   contour_side1_length
#   contour_side2
#   contour_side2_length
#   contour_width
#   intensity_analysis
#   intensity_analysis/switched_head_tail
#   plate_worms
#   provenance_tracking
#   provenance_tracking/BLOB_FEATS
#   provenance_tracking/INT_SKE_ORIENT
#   provenance_tracking/SKE_CREATE
#   provenance_tracking/SKE_FILT
#   provenance_tracking/SKE_INIT
#   provenance_tracking/SKE_ORIENT
#   provenance_tracking/TRAJ_CREATE
#   provenance_tracking/TRAJ_JOIN
#   skeleton
#   skeleton_length
#   timestamp
#   timestamp/raw
#   timestamp/time
#   trajectories_data
#   width_midbody
#
# Contents of the datasets:
#   Dataset: blob_features
#     Shape: (21223,)
#     Data Type: [('coord_x', '<f4'), ('coord_y', '<f4'), ('area', '<f4'), ('perimeter', '<f4'), ('box_length', '<f4'), ('box_width', '<f4'), ('quirkiness', '<f4'), ('compactness', '<f4'), ('box_orientation', '<f4'), ('solidity', '<f4'), ('intensity_mean', '<f4'), ('intensity_std', '<f4'), ('hu0', '<f4'), ('hu1', '<f4'), ('hu2', '<f4'), ('hu3', '<f4'), ('hu4', '<f4'), ('hu5', '<f4'), ('hu6', '<f4')]
#     Number of Elements: 21223
#     (Dataset too large to print completely)
#   Dataset: contour_area
#     Shape: (21223,)
#     Data Type: float32
#     Number of Elements: 21223
#     (Dataset too large to print completely)
#   Dataset: contour_side1
#     Shape: (21223, 49, 2)
#     Data Type: float32
#     Number of Elements: 2079854
#     (Dataset too large to print completely)
#   Dataset: contour_side1_length
#     Shape: (21223,)
#     Data Type: float32
#     Number of Elements: 21223
#     (Dataset too large to print completely)
#   Dataset: contour_side2
#     Shape: (21223, 49, 2)
#     Data Type: float32
#     Number of Elements: 2079854
#     (Dataset too large to print completely)
#   Dataset: contour_side2_length
#     Shape: (21223,)
#     Data Type: float32
#     Number of Elements: 21223
#     (Dataset too large to print completely)
#   Dataset: contour_width
#     Shape: (21223, 49)
#     Data Type: float32
#     Number of Elements: 1039927
#     (Dataset too large to print completely)
#   Group: intensity_analysis
#   Dataset: plate_worms
#     Shape: (24341,)
#     Data Type: [('worm_index_blob', '<i8'), ('worm_index_joined', '<i8'), ('frame_number', '<i8'), ('coord_x', '<f4'), ('coord_y', '<f4'), ('box_length', '<f4'), ('box_width', '<f4'), ('angle', '<f4'), ('area', '<f4'), ('bounding_box_xmin', '<f4'), ('bounding_box_xmax', '<f4'), ('bounding_box_ymin', '<f4'), ('bounding_box_ymax', '<f4'), ('threshold', '<f4')]
#     Number of Elements: 24341
#     (Dataset too large to print completely)
#   Group: provenance_tracking
#   Dataset: skeleton
#     Shape: (21223, 49, 2)
#     Data Type: float32
#     Number of Elements: 2079854
#     (Dataset too large to print completely)
#   Dataset: skeleton_length
#     Shape: (21223,)
#     Data Type: float32
#     Number of Elements: 21223
#     (Dataset too large to print completely)
#   Group: timestamp
#   Dataset: trajectories_data
#     Shape: (21223,)
#     Data Type: [('frame_number', '<i4'), ('worm_index_joined', '<i4'), ('plate_worm_id', '<i4'), ('skeleton_id', '<i4'), ('coord_x', '<f4'), ('coord_y', '<f4'), ('threshold', '<f4'), ('has_skeleton', 'u1'), ('roi_size', '<f4'), ('area', '<f4'), ('timestamp_raw', '<f4'), ('timestamp_time', '<f4'), ('is_good_skel', 'u1'), ('skel_outliers_flag', '<i8'), ('int_map_id', '<i8')]
#     Number of Elements: 21223
#     (Dataset too large to print completely)
#   Dataset: width_midbody
#     Shape: (21223,)
#     Data Type: float32
#     Number of Elements: 21223
#     (Dataset too large to print completely)
#
# ==============================
# Analyzing file: /content/drive/MyDrive/Worms/L2_featuresN.hdf5
# ==============================
# <HDF5 file "L2_featuresN.hdf5" (mode r)>
#
# HDF5 File Structure:
#   blob_features
#   coordinates
#   coordinates/dorsal_contours
#   coordinates/skeletons
#   coordinates/ventral_contours
#   coordinates/widths
#   features_stats
#   provenance_tracking
#   provenance_tracking/FEAT_INIT
#   provenance_tracking/FEAT_TIERPSY
#   timeseries_data
#   trajectories_data
#
# Contents of the datasets:
#   Dataset: blob_features
#     Shape: (14636,)
#     Data Type: [('coord_x', '<f8'), ('coord_y', '<f8'), ('area', '<f8'), ('perimeter', '<f8'), ('box_length', '<f8'), ('box_width', '<f8'), ('quirkiness', '<f4'), ('compactness', '<f4'), ('box_orientation', '<f4'), ('solidity', '<f4'), ('intensity_mean', '<f4'), ('intensity_std', '<f4'), ('hu0', '<f4'), ('hu1', '<f4'), ('hu2', '<f4'), ('hu3', '<f4'), ('hu4', '<f4'), ('hu5', '<f4'), ('hu6', '<f4')]
#     Number of Elements: 14636
#     (Dataset too large to print completely)
#   Group: coordinates
#   Dataset: features_stats
#     Shape: (4539,)
#     Data Type: [('name', 'S69'), ('value', '<f4')]
#     Number of Elements: 4539
#     (Dataset too large to print completely)
#   Group: provenance_tracking
#   Dataset: timeseries_data
#     Shape: (14636,)
#     Data Type: [('worm_index', '<i4'), ('timestamp', '<i4'), ('well_name', 'S3'), ('speed', '<f4'), ('angular_velocity', '<f4'), ('relative_to_body_speed_midbody', '<f4'), ('relative_to_body_radial_velocity_head_tip', '<f4'), ('relative_to_body_angular_velocity_head_tip', '<f4'), ('relative_to_body_radial_velocity_neck', '<f4'), ('relative_to_body_angular_velocity_neck', '<f4'), ('relative_to_body_radial_velocity_hips', '<f4'), ('relative_to_body_angular_velocity_hips', '<f4'), ('relative_to_body_radial_velocity_tail_tip', '<f4'), ('relative_to_body_angular_velocity_tail_tip', '<f4'), ('speed_neck', '<f4'), ('angular_velocity_neck', '<f4'), ('relative_to_neck_radial_velocity_head_tip', '<f4'), ('relative_to_neck_angular_velocity_head_tip', '<f4'), ('speed_head_base', '<f4'), ('angular_velocity_head_base', '<f4'), ('relative_to_head_base_radial_velocity_head_tip', '<f4'), ('relative_to_head_base_angular_velocity_head_tip', '<f4'), ('speed_hips', '<f4'), ('angular_velocity_hips', '<f4'), ('relative_to_hips_radial_velocity_tail_tip', '<f4'), ('relative_to_hips_angular_velocity_tail_tip', '<f4'), ('speed_tail_base', '<f4'), ('angular_velocity_tail_base', '<f4'), ('relative_to_tail_base_radial_velocity_tail_tip', '<f4'), ('relative_to_tail_base_angular_velocity_tail_tip', '<f4'), ('speed_midbody', '<f4'), ('angular_velocity_midbody', '<f4'), ('speed_head_tip', '<f4'), ('angular_velocity_head_tip', '<f4'), ('speed_tail_tip', '<f4'), ('angular_velocity_tail_tip', '<f4'), ('length', '<f4'), ('area', '<f4'), ('width_head_base', '<f4'), ('width_midbody', '<f4'), ('width_tail_base', '<f4'), ('quirkiness', '<f4'), ('major_axis', '<f4'), ('minor_axis', '<f4'), ('eigen_projection_1', '<f4'), ('eigen_projection_2', '<f4'), ('eigen_projection_3', '<f4'), ('eigen_projection_4', '<f4'), ('eigen_projection_5', '<f4'), ('eigen_projection_6', '<f4'), ('eigen_projection_7', '<f4'), ('curvature_head', '<f4'), ('curvature_hips', '<f4'), ('curvature_midbody', '<f4'), ('curvature_neck', '<f4'), ('curvature_tail', '<f4'), ('curvature_mean_head', '<f4'), ('curvature_mean_neck', '<f4'), ('curvature_mean_midbody', '<f4'), ('curvature_mean_hips', '<f4'), ('curvature_mean_tail', '<f4'), ('curvature_std_head', '<f4'), ('curvature_std_neck', '<f4'), ('curvature_std_midbody', '<f4'), ('curvature_std_hips', '<f4'), ('curvature_std_tail', '<f4'), ('orientation_food_edge', '<f4'), ('dist_from_food_edge', '<f4'), ('path_curvature_body', '<f4'), ('path_curvature_tail', '<f4'), ('path_curvature_midbody', '<f4'), ('path_curvature_head', '<f4'), ('d_speed', '<f4'), ('d_angular_velocity', '<f4'), ('d_relative_to_body_speed_midbody', '<f4'), ('d_relative_to_body_radial_velocity_head_tip', '<f4'), ('d_relative_to_body_angular_velocity_head_tip', '<f4'), ('d_relative_to_body_radial_velocity_neck', '<f4'), ('d_relative_to_body_angular_velocity_neck', '<f4'), ('d_relative_to_body_radial_velocity_hips', '<f4'), ('d_relative_to_body_angular_velocity_hips', '<f4'), ('d_relative_to_body_radial_velocity_tail_tip', '<f4'), ('d_relative_to_body_angular_velocity_tail_tip', '<f4'), ('d_speed_neck', '<f4'), ('d_angular_velocity_neck', '<f4'), ('d_relative_to_neck_radial_velocity_head_tip', '<f4'), ('d_relative_to_neck_angular_velocity_head_tip', '<f4'), ('d_speed_head_base', '<f4'), ('d_angular_velocity_head_base', '<f4'), ('d_relative_to_head_base_radial_velocity_head_tip', '<f4'), ('d_relative_to_head_base_angular_velocity_head_tip', '<f4'), ('d_speed_hips', '<f4'), ('d_angular_velocity_hips', '<f4'), ('d_relative_to_hips_radial_velocity_tail_tip', '<f4'), ('d_relative_to_hips_angular_velocity_tail_tip', '<f4'), ('d_speed_tail_base', '<f4'), ('d_angular_velocity_tail_base', '<f4'), ('d_relative_to_tail_base_radial_velocity_tail_tip', '<f4'), ('d_relative_to_tail_base_angular_velocity_tail_tip', '<f4'), ('d_speed_midbody', '<f4'), ('d_angular_velocity_midbody', '<f4'), ('d_speed_head_tip', '<f4'), ('d_angular_velocity_head_tip', '<f4'), ('d_speed_tail_tip', '<f4'), ('d_angular_veloci ...
#     Number of Elements: 14636
#     (Dataset too large to print completely)
#   Dataset: trajectories_data
#     Shape: (14636,)
#     Data Type: [('timestamp_raw', '<i4'), ('timestamp_time', '<f8'), ('worm_index_joined', '<i4'), ('coord_x', '<f4'), ('coord_y', '<f4'), ('threshold', '<f4'), ('roi_size', '<f4'), ('area', '<f4'), ('frame_number', '<i4'), ('was_skeletonized', 'u1'), ('skeleton_id', '<i8'), ('old_trajectory_data_index', '<i4'), ('worm_label', '<f8'), ('worm_index_manual', '<i4'), ('has_skeleton', 'u1')]
#     Number of Elements: 14636
#     (Dataset too large to print completely)
#
# ==============================
# Analyzing file: /content/drive/MyDrive/Worms/L2_intensities.hdf5
# ==============================
# <HDF5 file "L2_intensities.hdf5" (mode r)>
#
# HDF5 File Structure:
#   provenance_tracking
#   provenance_tracking/INT_PROFILE
#   straighten_worm_intensity_median
#   trajectories_data_valid
#
# Contents of the datasets:
#   Group: provenance_tracking
#   Dataset: straighten_worm_intensity_median
#     Shape: (10303, 131)
#     Data Type: float16
#     Number of Elements: 1349693
#     (Dataset too large to print completely)
#   Dataset: trajectories_data_valid
#     Shape: (10303,)
#     Data Type: [('frame_number', '<i4'), ('worm_index_joined', '<i4'), ('plate_worm_id', '<i4'), ('skeleton_id', '<i4'), ('coord_x', '<f4'), ('coord_y', '<f4'), ('threshold', '<f4'), ('has_skeleton', 'u1'), ('roi_size', '<f4'), ('area', '<f4'), ('timestamp_raw', '<f4'), ('timestamp_time', '<f4'), ('is_good_skel', 'u1'), ('skel_outliers_flag', '<i8'), ('int_map_id', '<i8')]
#     Number of Elements: 10303
#     (Dataset too large to print completely)
#
# ==============================
# Analyzing file: /content/drive/MyDrive/Worms/L2_skeletons.hdf5
# ==============================
# <HDF5 file "L2_skeletons.hdf5" (mode r)>
#
# HDF5 File Structure:
#   blob_features
#   contour_area
#   contour_side1
#   contour_side1_length
#   contour_side2
#   contour_side2_length
#   contour_width
#   intensity_analysis
#   intensity_analysis/switched_head_tail
#   plate_worms
#   provenance_tracking
#   provenance_tracking/BLOB_FEATS
#   provenance_tracking/INT_SKE_ORIENT
#   provenance_tracking/SKE_CREATE
#   provenance_tracking/SKE_FILT
#   provenance_tracking/SKE_INIT
#   provenance_tracking/SKE_ORIENT
#   provenance_tracking/TRAJ_CREATE
#   provenance_tracking/TRAJ_JOIN
#   skeleton
#   skeleton_length
#   timestamp
#   timestamp/raw
#   timestamp/time
#   trajectories_data
#   width_midbody
#
# Contents of the datasets:
#   Dataset: blob_features
#     Shape: (14636,)
#     Data Type: [('coord_x', '<f4'), ('coord_y', '<f4'), ('area', '<f4'), ('perimeter', '<f4'), ('box_length', '<f4'), ('box_width', '<f4'), ('quirkiness', '<f4'), ('compactness', '<f4'), ('box_orientation', '<f4'), ('solidity', '<f4'), ('intensity_mean', '<f4'), ('intensity_std', '<f4'), ('hu0', '<f4'), ('hu1', '<f4'), ('hu2', '<f4'), ('hu3', '<f4'), ('hu4', '<f4'), ('hu5', '<f4'), ('hu6', '<f4')]
#     Number of Elements: 14636
#     (Dataset too large to print completely)
#   Dataset: contour_area
#     Shape: (14636,)
#     Data Type: float32
#     Number of Elements: 14636
#     (Dataset too large to print completely)
#   Dataset: contour_side1
#     Shape: (14636, 49, 2)
#     Data Type: float32
#     Number of Elements: 1434328
#     (Dataset too large to print completely)
#   Dataset: contour_side1_length
#     Shape: (14636,)
#     Data Type: float32
#     Number of Elements: 14636
#     (Dataset too large to print completely)
#   Dataset: contour_side2
#     Shape: (14636, 49, 2)
#     Data Type: float32
#     Number of Elements: 1434328
#     (Dataset too large to print completely)
#   Dataset: contour_side2_length
#     Shape: (14636,)
#     Data Type: float32
#     Number of Elements: 14636
#     (Dataset too large to print completely)
#   Dataset: contour_width
#     Shape: (14636, 49)
#     Data Type: float32
#     Number of Elements: 717164
#     (Dataset too large to print completely)
#   Group: intensity_analysis
#   Dataset: plate_worms
#     Shape: (14879,)
#     Data Type: [('worm_index_blob', '<i8'), ('worm_index_joined', '<i8'), ('frame_number', '<i8'), ('coord_x', '<f4'), ('coord_y', '<f4'), ('box_length', '<f4'), ('box_width', '<f4'), ('angle', '<f4'), ('area', '<f4'), ('bounding_box_xmin', '<f4'), ('bounding_box_xmax', '<f4'), ('bounding_box_ymin', '<f4'), ('bounding_box_ymax', '<f4'), ('threshold', '<f4')]
#     Number of Elements: 14879
#     (Dataset too large to print completely)
#   Group: provenance_tracking
#   Dataset: skeleton
#     Shape: (14636, 49, 2)
#     Data Type: float32
#     Number of Elements: 1434328
#     (Dataset too large to print completely)
#   Dataset: skeleton_length
#     Shape: (14636,)
#     Data Type: float32
#     Number of Elements: 14636
#     (Dataset too large to print completely)
#   Group: timestamp
#   Dataset: trajectories_data
#     Shape: (14636,)
#     Data Type: [('frame_number', '<i4'), ('worm_index_joined', '<i4'), ('plate_worm_id', '<i4'), ('skeleton_id', '<i4'), ('coord_x', '<f4'), ('coord_y', '<f4'), ('threshold', '<f4'), ('has_skeleton', 'u1'), ('roi_size', '<f4'), ('area', '<f4'), ('timestamp_raw', '<f4'), ('timestamp_time', '<f4'), ('is_good_skel', 'u1'), ('skel_outliers_flag', '<i8'), ('int_map_id', '<i8')]
#     Number of Elements: 14636
#     (Dataset too large to print completely)
#   Dataset: width_midbody
#     Shape: (14636,)
#     Data Type: float32
#     Number of Elements: 14636
#     (Dataset too large to print completely)
#
# ==============================
# Analyzing file: /content/drive/MyDrive/Worms/n2_featuresN.hdf5
# ==============================
# <HDF5 file "n2_featuresN.hdf5" (mode r)>
#
# HDF5 File Structure:
#   blob_features
#   coordinates
#   coordinates/dorsal_contours
#   coordinates/skeletons
#   coordinates/ventral_contours
#   coordinates/widths
#   features_stats
#   provenance_tracking
#   provenance_tracking/FEAT_INIT
#   provenance_tracking/FEAT_TIERPSY
#   timeseries_data
#   trajectories_data
#
# Contents of the datasets:
#   Dataset: blob_features
#     Shape: (23324,)
#     Data Type: [('coord_x', '<f8'), ('coord_y', '<f8'), ('area', '<f8'), ('perimeter', '<f8'), ('box_length', '<f8'), ('box_width', '<f8'), ('quirkiness', '<f4'), ('compactness', '<f4'), ('box_orientation', '<f4'), ('solidity', '<f4'), ('intensity_mean', '<f4'), ('intensity_std', '<f4'), ('hu0', '<f4'), ('hu1', '<f4'), ('hu2', '<f4'), ('hu3', '<f4'), ('hu4', '<f4'), ('hu5', '<f4'), ('hu6', '<f4')]
#     Number of Elements: 23324
#     (Dataset too large to print completely)
#   Group: coordinates
#   Dataset: features_stats
#     Shape: (4539,)
#     Data Type: [('name', 'S69'), ('value', '<f4')]
#     Number of Elements: 4539
#     (Dataset too large to print completely)
#   Group: provenance_tracking
#   Dataset: timeseries_data
#     Shape: (23324,)
#     Data Type: [('worm_index', '<i4'), ('timestamp', '<i4'), ('well_name', 'S3'), ('speed', '<f4'), ('angular_velocity', '<f4'), ('relative_to_body_speed_midbody', '<f4'), ('relative_to_body_radial_velocity_head_tip', '<f4'), ('relative_to_body_angular_velocity_head_tip', '<f4'), ('relative_to_body_radial_velocity_neck', '<f4'), ('relative_to_body_angular_velocity_neck', '<f4'), ('relative_to_body_radial_velocity_hips', '<f4'), ('relative_to_body_angular_velocity_hips', '<f4'), ('relative_to_body_radial_velocity_tail_tip', '<f4'), ('relative_to_body_angular_velocity_tail_tip', '<f4'), ('speed_neck', '<f4'), ('angular_velocity_neck', '<f4'), ('relative_to_neck_radial_velocity_head_tip', '<f4'), ('relative_to_neck_angular_velocity_head_tip', '<f4'), ('speed_head_base', '<f4'), ('angular_velocity_head_base', '<f4'), ('relative_to_head_base_radial_velocity_head_tip', '<f4'), ('relative_to_head_base_angular_velocity_head_tip', '<f4'), ('speed_hips', '<f4'), ('angular_velocity_hips', '<f4'), ('relative_to_hips_radial_velocity_tail_tip', '<f4'), ('relative_to_hips_angular_velocity_tail_tip', '<f4'), ('speed_tail_base', '<f4'), ('angular_velocity_tail_base', '<f4'), ('relative_to_tail_base_radial_velocity_tail_tip', '<f4'), ('relative_to_tail_base_angular_velocity_tail_tip', '<f4'), ('speed_midbody', '<f4'), ('angular_velocity_midbody', '<f4'), ('speed_head_tip', '<f4'), ('angular_velocity_head_tip', '<f4'), ('speed_tail_tip', '<f4'), ('angular_velocity_tail_tip', '<f4'), ('length', '<f4'), ('area', '<f4'), ('width_head_base', '<f4'), ('width_midbody', '<f4'), ('width_tail_base', '<f4'), ('quirkiness', '<f4'), ('major_axis', '<f4'), ('minor_axis', '<f4'), ('eigen_projection_1', '<f4'), ('eigen_projection_2', '<f4'), ('eigen_projection_3', '<f4'), ('eigen_projection_4', '<f4'), ('eigen_projection_5', '<f4'), ('eigen_projection_6', '<f4'), ('eigen_projection_7', '<f4'), ('curvature_head', '<f4'), ('curvature_hips', '<f4'), ('curvature_midbody', '<f4'), ('curvature_neck', '<f4'), ('curvature_tail', '<f4'), ('curvature_mean_head', '<f4'), ('curvature_mean_neck', '<f4'), ('curvature_mean_midbody', '<f4'), ('curvature_mean_hips', '<f4'), ('curvature_mean_tail', '<f4'), ('curvature_std_head', '<f4'), ('curvature_std_neck', '<f4'), ('curvature_std_midbody', '<f4'), ('curvature_std_hips', '<f4'), ('curvature_std_tail', '<f4'), ('orientation_food_edge', '<f4'), ('dist_from_food_edge', '<f4'), ('path_curvature_body', '<f4'), ('path_curvature_tail', '<f4'), ('path_curvature_midbody', '<f4'), ('path_curvature_head', '<f4'), ('d_speed', '<f4'), ('d_angular_velocity', '<f4'), ('d_relative_to_body_speed_midbody', '<f4'), ('d_relative_to_body_radial_velocity_head_tip', '<f4'), ('d_relative_to_body_angular_velocity_head_tip', '<f4'), ('d_relative_to_body_radial_velocity_neck', '<f4'), ('d_relative_to_body_angular_velocity_neck', '<f4'), ('d_relative_to_body_radial_velocity_hips', '<f4'), ('d_relative_to_body_angular_velocity_hips', '<f4'), ('d_relative_to_body_radial_velocity_tail_tip', '<f4'), ('d_relative_to_body_angular_velocity_tail_tip', '<f4'), ('d_speed_neck', '<f4'), ('d_angular_velocity_neck', '<f4'), ('d_relative_to_neck_radial_velocity_head_tip', '<f4'), ('d_relative_to_neck_angular_velocity_head_tip', '<f4'), ('d_speed_head_base', '<f4'), ('d_angular_velocity_head_base', '<f4'), ('d_relative_to_head_base_radial_velocity_head_tip', '<f4'), ('d_relative_to_head_base_angular_velocity_head_tip', '<f4'), ('d_speed_hips', '<f4'), ('d_angular_velocity_hips', '<f4'), ('d_relative_to_hips_radial_velocity_tail_tip', '<f4'), ('d_relative_to_hips_angular_velocity_tail_tip', '<f4'), ('d_speed_tail_base', '<f4'), ('d_angular_velocity_tail_base', '<f4'), ('d_relative_to_tail_base_radial_velocity_tail_tip', '<f4'), ('d_relative_to_tail_base_angular_velocity_tail_tip', '<f4'), ('d_speed_midbody', '<f4'), ('d_angular_velocity_midbody', '<f4'), ('d_speed_head_tip', '<f4'), ('d_angular_velocity_head_tip', '<f4'), ('d_speed_tail_tip', '<f4'), ('d_angular_veloci ...
#     Number of Elements: 23324
#     (Dataset too large to print completely)
#   Dataset: trajectories_data
#     Shape: (23324,)
#     Data Type: [('timestamp_raw', '<i4'), ('timestamp_time', '<f8'), ('worm_index_joined', '<i4'), ('coord_x', '<f4'), ('coord_y', '<f4'), ('threshold', '<f4'), ('roi_size', '<f4'), ('area', '<f4'), ('frame_number', '<i4'), ('was_skeletonized', 'u1'), ('skeleton_id', '<i8'), ('old_trajectory_data_index', '<i4'), ('worm_label', '<f8'), ('worm_index_manual', '<i4'), ('has_skeleton', 'u1')]
#     Number of Elements: 23324
#     (Dataset too large to print completely)
#
# ==============================
# Analyzing file: /content/drive/MyDrive/Worms/n2_intensities.hdf5
# ==============================
# <HDF5 file "n2_intensities.hdf5" (mode r)>
#
# HDF5 File Structure:
#   provenance_tracking
#   provenance_tracking/INT_PROFILE
#   straighten_worm_intensity_median
#   trajectories_data_valid
#
# Contents of the datasets:
#   Group: provenance_tracking
#   Dataset: straighten_worm_intensity_median
#     Shape: (18598, 131)
#     Data Type: float16
#     Number of Elements: 2436338
#     (Dataset too large to print completely)
#   Dataset: trajectories_data_valid
#     Shape: (18598,)
#     Data Type: [('frame_number', '<i4'), ('worm_index_joined', '<i4'), ('plate_worm_id', '<i4'), ('skeleton_id', '<i4'), ('coord_x', '<f4'), ('coord_y', '<f4'), ('threshold', '<f4'), ('has_skeleton', 'u1'), ('roi_size', '<f4'), ('area', '<f4'), ('timestamp_raw', '<f4'), ('timestamp_time', '<f4'), ('is_good_skel', 'u1'), ('skel_outliers_flag', '<i8'), ('int_map_id', '<i8')]
#     Number of Elements: 18598
#     (Dataset too large to print completely)
#
# ==============================
# Analyzing file: /content/drive/MyDrive/Worms/n2_skeletons.hdf5
# ==============================
# <HDF5 file "n2_skeletons.hdf5" (mode r)>
#
# HDF5 File Structure:
#   blob_features
#   contour_area
#   contour_side1
#   contour_side1_length
#   contour_side2
#   contour_side2_length
#   contour_width
#   intensity_analysis
#   intensity_analysis/switched_head_tail
#   plate_worms
#   provenance_tracking
#   provenance_tracking/BLOB_FEATS
#   provenance_tracking/INT_SKE_ORIENT
#   provenance_tracking/SKE_CREATE
#   provenance_tracking/SKE_FILT
#   provenance_tracking/SKE_INIT
#   provenance_tracking/SKE_ORIENT
#   provenance_tracking/TRAJ_CREATE
#   provenance_tracking/TRAJ_JOIN
#   skeleton
#   skeleton_length
#   timestamp
#   timestamp/raw
#   timestamp/time
#   trajectories_data
#   width_midbody
#
# Contents of the datasets:
#   Dataset: blob_features
#     Shape: (23324,)
#     Data Type: [('coord_x', '<f4'), ('coord_y', '<f4'), ('area', '<f4'), ('perimeter', '<f4'), ('box_length', '<f4'), ('box_width', '<f4'), ('quirkiness', '<f4'), ('compactness', '<f4'), ('box_orientation', '<f4'), ('solidity', '<f4'), ('intensity_mean', '<f4'), ('intensity_std', '<f4'), ('hu0', '<f4'), ('hu1', '<f4'), ('hu2', '<f4'), ('hu3', '<f4'), ('hu4', '<f4'), ('hu5', '<f4'), ('hu6', '<f4')]
#     Number of Elements: 23324
#     (Dataset too large to print completely)
#   Dataset: contour_area
#     Shape: (23324,)
#     Data Type: float32
#     Number of Elements: 23324
#     (Dataset too large to print completely)
#   Dataset: contour_side1
#     Shape: (23324, 49, 2)
#     Data Type: float32
#     Number of Elements: 2285752
#     (Dataset too large to print completely)
#   Dataset: contour_side1_length
#     Shape: (23324,)
#     Data Type: float32
#     Number of Elements: 23324
#     (Dataset too large to print completely)
#   Dataset: contour_side2
#     Shape: (23324, 49, 2)
#     Data Type: float32
#     Number of Elements: 2285752
#     (Dataset too large to print completely)
#   Dataset: contour_side2_length
#     Shape: (23324,)
#     Data Type: float32
#     Number of Elements: 23324
#     (Dataset too large to print completely)
#   Dataset: contour_width
#     Shape: (23324, 49)
#     Data Type: float32
#     Number of Elements: 1142876
#     (Dataset too large to print completely)
#   Group: intensity_analysis
#   Dataset: plate_worms
#     Shape: (24866,)
#     Data Type: [('worm_index_blob', '<i8'), ('worm_index_joined', '<i8'), ('frame_number', '<i8'), ('coord_x', '<f4'), ('coord_y', '<f4'), ('box_length', '<f4'), ('box_width', '<f4'), ('angle', '<f4'), ('area', '<f4'), ('bounding_box_xmin', '<f4'), ('bounding_box_xmax', '<f4'), ('bounding_box_ymin', '<f4'), ('bounding_box_ymax', '<f4'), ('threshold', '<f4')]
#     Number of Elements: 24866
#     (Dataset too large to print completely)
#   Group: provenance_tracking
#   Dataset: skeleton
#     Shape: (23324, 49, 2)
#     Data Type: float32
#     Number of Elements: 2285752
#     (Dataset too large to print completely)
#   Dataset: skeleton_length
#     Shape: (23324,)
#     Data Type: float32
#     Number of Elements: 23324
#     (Dataset too large to print completely)
#   Group: timestamp
#   Dataset: trajectories_data
#     Shape: (23324,)
#     Data Type: [('frame_number', '<i4'), ('worm_index_joined', '<i4'), ('plate_worm_id', '<i4'), ('skeleton_id', '<i4'), ('coord_x', '<f4'), ('coord_y', '<f4'), ('threshold', '<f4'), ('has_skeleton', 'u1'), ('roi_size', '<f4'), ('area', '<f4'), ('timestamp_raw', '<f4'), ('timestamp_time', '<f4'), ('is_good_skel', 'u1'), ('skel_outliers_flag', '<i8'), ('int_map_id', '<i8')]
#     Number of Elements: 23324
#     (Dataset too large to print completely)
#   Dataset: width_midbody
#     Shape: (23324,)
#     Data Type: float32
#     Number of Elements: 23324
#     (Dataset too large to print completely)

# %%
hdFileName = '/content/drive/MyDrive/Worms/L1_featuresN.hdf5'
dataset_name = 'blob_features'

try:
    with h5py.File(hdFileName, 'r') as hdfid:
        if dataset_name in hdfid:
            dataset = hdfid[dataset_name]
            print(f"Dataset: {dataset_name}")
            print(f"  Shape: {dataset.shape}")
            print(f"  Data Type (dtype): {dataset.dtype}")
            print("  First 5 rows:")
            print(dataset[:5])
        else:
            print(f"Error: The dataset '{dataset_name}' was not found in the file '{hdFileName}'.")

except FileNotFoundError:
    print(f"Error: The file '{hdFileName}' was not found.")
except Exception as e:
    print(f"An error occurred while opening or reading the file: {e}")
# Out:
# Dataset: blob_features
#   Shape: (21223,)
#   Data Type (dtype): [('coord_x', '<f8'), ('coord_y', '<f8'), ('area', '<f8'), ('perimeter', '<f8'), ('box_length', '<f8'), ('box_width', '<f8'), ('quirkiness', '<f4'), ('compactness', '<f4'), ('box_orientation', '<f4'), ('solidity', '<f4'), ('intensity_mean', '<f4'), ('intensity_std', '<f4'), ('hu0', '<f4'), ('hu1', '<f4'), ('hu2', '<f4'), ('hu3', '<f4'), ('hu4', '<f4'), ('hu5', '<f4'), ('hu6', '<f4')]
#   First 5 rows:
# [(1054.58703613, 1563.48974609, 410.5, 137.43859863, 49.01330948, 17.63538551, 0.9330263 , 0.27308986, -70.14479 , 0.5864286 , 115.01068, 9.011264, 0.4606221 , 0.1471695 , 0.00379843, 0.00109636, 1.9368704e-06, 0.00016743, -1.1199185e-06)
#  (1054.58618164, 1564.46142578, 373.5, 137.78173828, 48.50436401, 17.17677498, 0.9351968 , 0.24723908, -69.14554 , 0.5693598 , 114.46296, 8.518961, 0.494695  , 0.16593784, 0.0041463 , 0.00452903, 1.9620735e-05, 0.00183178,  4.6712040e-07)
#  (1054.74133301, 1564.10339355, 396. , 143.6812439 , 48.97730637, 18.51421165, 0.925799  , 0.24104877, -66.80141 , 0.5553997 , 115.23465, 8.603841, 0.46912497, 0.14197958, 0.00584746, 0.00413408, 2.0320515e-05, 0.00155724,  4.7201596e-07)
#  (1054.7121582 , 1564.7902832 , 396.5, 144.26702881, 52.52196121, 18.71793365, 0.93433994, 0.23939711, -65.22485 , 0.54315066, 114.84026, 8.682251, 0.52388936, 0.18399715, 0.01258522, 0.00604597, 5.2275085e-05, 0.00254031,  6.9770667e-06)
#  (1053.75756836, 1566.34716797, 425. , 130.7106781 , 48.86223602, 19.24187279, 0.9191968 , 0.31259114, -65.376434, 0.6058446 , 115.91061, 9.280919, 0.39915666, 0.10043266, 0.00602296, 0.00234125, 8.4988760e-06, 0.00066439,  2.2504578e-06)]
